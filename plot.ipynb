# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
sns.set_style('darkgrid')

# %%
data = np.load('data/arrays/prompt_5000_out.npy')
data = data[:, 1]
sns.lineplot(x=np.arange(len(data)), y=data);
